# %%
from symbulate import *
# %matplotlib inline

# %%
X = RV(Normal(mean = 70, sd = 10))
x = X.sim(100)
x.plot('rug')

# %%
x.plot(['rug', 'hist'])

# %%
X.sim(10000).plot()
Normal(70, 10).plot()

# %%
Z = RV(Normal(0, 1))
X = 49.8 + 1.3 * Z
X.sim(10000).plot()
Normal(49.8, 1.3).plot()

# %%
X = RV(Normal(mean = 49.8, sd = 1.3))

# %%
X.sim(100).plot('rug')

# %%
x = X.sim(10000)
x.plot()
Normal(mean = 49.8, sd = 1.3).plot()
x.mean(), x.sd(), x.count_lt(47.9) / x.count()
# Out:
# (49.80058517489423, 1.2985858735851175, 0.0719)

# %%
z = (47.9 - 49.8) / 1.3
z, Normal(mean = 0, sd = 1).cdf(z)
# Out:
# (-1.4615384615384603, 0.07193386424080776)

# %%
Normal(mean = 49.8, sd = 1.3).cdf(47.9)
# Out:
# 0.07193386424080776

# %%
z = (53.0 - 49.8) / 1.3
z = Normal(mean = 0, sd = 1).cdf(z)

# %%
Normal().cdf(2.46)
# Out:
# 0.9930531492113757

# %%
Normal(mean = 0, sd = 1).quantile(0.01)
# Out:
# -2.3263478740408408

# %%
Normal(mean = 49.8, sd = 1.3).quantile(0.01)
# Out:
# 46.77574776374691

# %%
Normal(mean = 0, sd = 1).quantile(0.25)
# Out:
# -0.6744897501960817

# %%
Normal(mean = 0, sd = 1).quantile(0.75)
# Out:
# 0.6744897501960817

# %%
49.8 + 1.3 * Normal(mean = 0, sd = 1).quantile(0.25)
# Out:
# 48.92316332474509

# %%
49.8 + 1.3 * Normal(mean = 0, sd = 1).quantile(0.75)
# Out:
# 50.676836675254904
